# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Reading the data

# %%
vehicle_df = pd.read_excel('Vehcile_Data.xlsx')
vehicle_df.shape
# Out:
# (100, 5)

# %%
vehicle_charging_df = pd.read_excel('Vehcile_Charging_Data.xlsx')
vehicle_charging_df
# Out:
#    Year  TruckType  Range(Kms)  VehicleBatteryCapacity(Kwh)  \
# 0  2025          1         400                        360.0
# 1  2026          1         500                        450.0
# 2  2027          1         550                        495.0
# 3  2028          1         550                        522.5
# 4  2029          1         570                        541.5
# 5  2025          2         420                        378.0
# 6  2026          2         520                        468.0
# 7  2027          2         570                        513.0
# 8  2028          2         580                        551.0
# 9  2029          2         580                        551.0
#
#    FuelConsumption(Unit/km)
# 0                      0.90
# 1                      0.90
# 2                      0.90
# 3                      0.95
# 4                      0.95
# 5                      0.90
# 6                      0.90
# 7                      0.90
# 8                      0.95
# 9                      0.95

# %%
energy_profile_df = pd.read_excel('Energy_Profile_Data.xlsx')
energy_profile_df
# Out:
#   SlotsOfDay  BaseLoadConsumption(kWh)  GridElectricityPrice (USD / kWh)  \
# 0  12AM-6 AM                    7.1542                              0.15
# 1  6AM-12 PM                    3.9840                              0.20
# 2   12PM-6PM                    3.1175                              0.25
# 3   6PM-12AM                    7.0860                              0.35
#
#    SolarUnitsGeneration in Kwh/KwP
# 0                              0.0
# 1                              1.4
# 2                              1.8
# 3                              0.8

# %%
infra_procurement_df = pd.read_excel('Infra_Procurement_Costs.xlsx')
infra_procurement_df
# Out:
#    Year  Battery(USD/kWh)  SolarPV(USD/kWp)  Charger 50KW (USD/unit)  \
# 0  2025               300               450                     1000
# 1  2026               286               450                     1000
# 2  2027               272               450                     1000
# 3  2028               259               450                     1000
# 4  2029               247               450                     1000
# 5  2030               235               450                     1000
# 6  2031               224               360                     1000
# 7  2032               213               360                     1000
# 8  2033               203               360                     1000
# 9  2034               193               360                     1000
#
#    Charger 400KW(USD/unit)
# 0                     2500
# 1                     2500
# 2                     2500
# 3                     2500
# 4                     2500
# 5                     2500
# 6                     2500
# 7                     2500
# 8                     2500
# 9                     2500

# %% [markdown]
# ## Getting only infra procurement costs from 2025 to 2029¶

# %%
years_needed = [2025, 2026, 2027, 2028, 2029]
infra_costs_5yr = infra_procurement_df[infra_procurement_df["Year"].isin(years_needed)].copy()
infra_costs_5yr
# Out:
#    Year  Battery(USD/kWh)  SolarPV(USD/kWp)  Charger 50KW (USD/unit)  \
# 0  2025               300               450                     1000
# 1  2026               286               450                     1000
# 2  2027               272               450                     1000
# 3  2028               259               450                     1000
# 4  2029               247               450                     1000
#
#    Charger 400KW(USD/unit)
# 0                     2500
# 1                     2500
# 2                     2500
# 3                     2500
# 4                     2500

# %% [markdown]
# ## Merging vehicle data and charging data on year, trucktype to get fuel consumption (unit /km)

# %%
vehicle_with_fc = vehicle_df.merge(
    vehicle_charging_df[["Year", "TruckType", "FuelConsumption(Unit/km)"]],
    on=["Year", "TruckType"],
    how="left"
)
vehicle_with_fc
# Out:
#     VehicleID  TruckType  Year  DailyRange(Kms) ChargingSlot  \
# 0   V001_2025          1  2025              250     6AM-12PM
# 1   V002_2025          1  2025              250     12PM-6PM
# 2   V003_2025          1  2025              250     6PM-12AM
# 3   V004_2025          1  2025              250     12AM-6AM
# 4   V005_2025          2  2025              280     6AM-12PM
# ..        ...        ...   ...              ...          ...
# 95  V026_2029          1  2029              330     12PM-6PM
# 96  V027_2029          1  2029              330     6AM-12PM
# 97  V028_2029          1  2029              330     12PM-6PM
# 98  V029_2029          1  2029              330     6PM-12AM
# 99  V030_2029          2  2029              360     12PM-6PM
#
#     FuelConsumption(Unit/km)
# 0                       0.90
# 1                       0.90
# 2                       0.90
# 3                       0.90
# 4                       0.90
# ..                       ...
# 95                      0.95
# 96                      0.95
# 97                      0.95
# 98                      0.95
# 99                      0.95
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Getting Energy requirement per truck as range * fuel consumption

# %%
vehicle_with_fc['Energy_Requirement_Per_Truck'] = vehicle_with_fc['DailyRange(Kms)']*vehicle_with_fc['FuelConsumption(Unit/km)']
vehicle_with_fc
# Out:
#     VehicleID  TruckType  Year  DailyRange(Kms) ChargingSlot  \
# 0   V001_2025          1  2025              250     6AM-12PM
# 1   V002_2025          1  2025              250     12PM-6PM
# 2   V003_2025          1  2025              250     6PM-12AM
# 3   V004_2025          1  2025              250     12AM-6AM
# 4   V005_2025          2  2025              280     6AM-12PM
# ..        ...        ...   ...              ...          ...
# 95  V026_2029          1  2029              330     12PM-6PM
# 96  V027_2029          1  2029              330     6AM-12PM
# 97  V028_2029          1  2029              330     12PM-6PM
# 98  V029_2029          1  2029              330     6PM-12AM
# 99  V030_2029          2  2029              360     12PM-6PM
#
#     FuelConsumption(Unit/km)  Energy_Requirement_Per_Truck
# 0                       0.90                         225.0
# 1                       0.90                         225.0
# 2                       0.90                         225.0
# 3                       0.90                         225.0
# 4                       0.90                         252.0
# ..                       ...                           ...
# 95                      0.95                         313.5
# 96                      0.95                         313.5
# 97                      0.95                         313.5
# 98                      0.95                         313.5
# 99                      0.95                         342.0
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Creating a slot map to make sure time slots can be listed as 1,2,3,4 for easier use later

# %%
slot_map = {
    "12AM-6AM": 1,
    "6AM-12PM": 2,
    "12PM-6PM": 3,
    "6PM-12AM": 4
}

vehicle_with_fc["SlotID"] = vehicle_with_fc["ChargingSlot"].map(slot_map)
vehicle_with_fc.head()
# Out:
#    VehicleID  TruckType  Year  DailyRange(Kms) ChargingSlot  \
# 0  V001_2025          1  2025              250     6AM-12PM
# 1  V002_2025          1  2025              250     12PM-6PM
# 2  V003_2025          1  2025              250     6PM-12AM
# 3  V004_2025          1  2025              250     12AM-6AM
# 4  V005_2025          2  2025              280     6AM-12PM
#
#    FuelConsumption(Unit/km)  Energy_Requirement_Per_Truck  SlotID
# 0                       0.9                         225.0       2
# 1                       0.9                         225.0       3
# 2                       0.9                         225.0       4
# 3                       0.9                         225.0       1
# 4                       0.9                         252.0       2

# %%
slot_map_energy = {
    "12AM-6 AM": 1,
    "6AM-12 PM": 2,
    "12PM-6PM": 3,
    "6PM-12AM": 4
}

energy_profile_df["SlotID"] = energy_profile_df["SlotsOfDay"].map(slot_map_energy)
energy_profile_df.head()
# Out:
#   SlotsOfDay  BaseLoadConsumption(kWh)  GridElectricityPrice (USD / kWh)  \
# 0  12AM-6 AM                    7.1542                              0.15
# 1  6AM-12 PM                    3.9840                              0.20
# 2   12PM-6PM                    3.1175                              0.25
# 3   6PM-12AM                    7.0860                              0.35
#
#    SolarUnitsGeneration in Kwh/KwP  SlotID
# 0                              0.0       1
# 1                              1.4       2
# 2                              1.8       3
# 3                              0.8       4

# %% [markdown]
# ## Merging with energy data to ensure grid price, solar generation and baseload cosnumption are present with vehicle data and vehicle charging data

# %%
vehicle_with_energy = vehicle_with_fc.merge(
    energy_profile_df[["SlotID", "BaseLoadConsumption(kWh)", 
                       "GridElectricityPrice (USD / kWh)",
                       "SolarUnitsGeneration in Kwh/KwP"]],
    on="SlotID",
    how="left"
)
vehicle_with_energy
# Out:
#     VehicleID  TruckType  Year  DailyRange(Kms) ChargingSlot  \
# 0   V001_2025          1  2025              250     6AM-12PM
# 1   V002_2025          1  2025              250     12PM-6PM
# 2   V003_2025          1  2025              250     6PM-12AM
# 3   V004_2025          1  2025              250     12AM-6AM
# 4   V005_2025          2  2025              280     6AM-12PM
# ..        ...        ...   ...              ...          ...
# 95  V026_2029          1  2029              330     12PM-6PM
# 96  V027_2029          1  2029              330     6AM-12PM
# 97  V028_2029          1  2029              330     12PM-6PM
# 98  V029_2029          1  2029              330     6PM-12AM
# 99  V030_2029          2  2029              360     12PM-6PM
#
#     FuelConsumption(Unit/km)  Energy_Requirement_Per_Truck  SlotID  \
# 0                       0.90                         225.0       2
# 1                       0.90                         225.0       3
# 2                       0.90                         225.0       4
# 3                       0.90                         225.0       1
# 4                       0.90                         252.0       2
# ..                       ...                           ...     ...
# 95                      0.95                         313.5       3
# 96                      0.95                         313.5       2
# 97                      0.95                         313.5       3
# 98                      0.95                         313.5       4
# 99                      0.95                         342.0       3
#
#     BaseLoadConsumption(kWh)  GridElectricityPrice (USD / kWh)  \
# 0                     3.9840                              0.20
# 1                     3.1175                              0.25
# 2                     7.0860                              0.35
# 3                     7.1542                              0.15
# 4                     3.9840                              0.20
# ..                       ...                               ...
# 95                    3.1175                              0.25
# 96                    3.9840                              0.20
# 97                    3.1175                              0.25
# 98                    7.0860                              0.35
# 99                    3.1175                              0.25
#
#     SolarUnitsGeneration in Kwh/KwP
# 0                               1.4
# 1                               1.8
# 2                               0.8
# 3                               0.0
# 4                               1.4
# ..                              ...
# 95                              1.8
# 96                              1.4
# 97                              1.8
# 98                              0.8
# 99                              1.8
#
# [100 rows x 11 columns]

# %% [markdown]
# ## Getting the requirements per slot by using group by on year and slot Id, sums up all trucks using that slot for charging¶

# %%
slot_charging_req = (
    vehicle_with_energy.groupby(["Year", "SlotID"])["Energy_Requirement_Per_Truck"]
    .sum()
    .reset_index()
    .rename(columns={"Energy_Requirement_Per_Truck": "ChargingRequirement"})
)
slot_charging_req
# Out:
#     Year  SlotID  ChargingRequirement
# 0   2025       1                477.0
# 1   2025       2                702.0
# 2   2025       3                729.0
# 3   2025       4                477.0
# 4   2026       1                477.0
# 5   2026       2               1197.0
# 6   2026       3               1233.0
# 7   2026       4                720.0
# 8   2027       1               1008.0
# 9   2027       2               1764.0
# 10  2027       3               1260.0
# 11  2027       4               1008.0
# 12  2028       1               1121.0
# 13  2028       2               2213.5
# 14  2028       3               2147.0
# 15  2028       4               1358.5
# 16  2029       1               1102.0
# 17  2029       2               2508.0
# 18  2029       3               3097.0
# 19  2029       4               1653.0

# %% [markdown]
# ## Merging slot data with energy profile for the same reason as before, to get base load, grid price and solar units.¶

# %%
slot_data = slot_charging_req.merge(
    energy_profile_df[["SlotID",
                       "BaseLoadConsumption(kWh)",
                       "GridElectricityPrice (USD / kWh)",
                       "SolarUnitsGeneration in Kwh/KwP"]],
    on="SlotID",
    how="left"
)
slot_data
# Out:
#     Year  SlotID  ChargingRequirement  BaseLoadConsumption(kWh)  \
# 0   2025       1                477.0                    7.1542
# 1   2025       2                702.0                    3.9840
# 2   2025       3                729.0                    3.1175
# 3   2025       4                477.0                    7.0860
# 4   2026       1                477.0                    7.1542
# 5   2026       2               1197.0                    3.9840
# 6   2026       3               1233.0                    3.1175
# 7   2026       4                720.0                    7.0860
# 8   2027       1               1008.0                    7.1542
# 9   2027       2               1764.0                    3.9840
# 10  2027       3               1260.0                    3.1175
# 11  2027       4               1008.0                    7.0860
# 12  2028       1               1121.0                    7.1542
# 13  2028       2               2213.5                    3.9840
# 14  2028       3               2147.0                    3.1175
# 15  2028       4               1358.5                    7.0860
# 16  2029       1               1102.0                    7.1542
# 17  2029       2               2508.0                    3.9840
# 18  2029       3               3097.0                    3.1175
# 19  2029       4               1653.0                    7.0860
#
#     GridElectricityPrice (USD / kWh)  SolarUnitsGeneration in Kwh/KwP
# 0                               0.15                              0.0
# 1                               0.20                              1.4
# 2                               0.25                              1.8
# 3                               0.35                              0.8
# 4                               0.15                              0.0
# 5                               0.20                              1.4
# 6                               0.25                              1.8
# 7                               0.35                              0.8
# 8                               0.15                              0.0
# 9                               0.20                              1.4
# 10                              0.25                              1.8
# 11                              0.35                              0.8
# 12                              0.15                              0.0
# 13                              0.20                              1.4
# 14                              0.25                              1.8
# 15                              0.35                              0.8
# 16                              0.15                              0.0
# 17                              0.20                              1.4
# 18                              0.25                              1.8
# 19                              0.35                              0.8

# %% [markdown]
# ## Total requirement in a slot = Charing Requirement + Base Load

# %%
slot_data["TotalEnergyRequirement"] = (
    slot_data["ChargingRequirement"] + slot_data["BaseLoadConsumption(kWh)"]
)

# %%
slot_data
# Out:
#     Year  SlotID  ChargingRequirement  BaseLoadConsumption(kWh)  \
# 0   2025       1                477.0                    7.1542
# 1   2025       2                702.0                    3.9840
# 2   2025       3                729.0                    3.1175
# 3   2025       4                477.0                    7.0860
# 4   2026       1                477.0                    7.1542
# 5   2026       2               1197.0                    3.9840
# 6   2026       3               1233.0                    3.1175
# 7   2026       4                720.0                    7.0860
# 8   2027       1               1008.0                    7.1542
# 9   2027       2               1764.0                    3.9840
# 10  2027       3               1260.0                    3.1175
# 11  2027       4               1008.0                    7.0860
# 12  2028       1               1121.0                    7.1542
# 13  2028       2               2213.5                    3.9840
# 14  2028       3               2147.0                    3.1175
# 15  2028       4               1358.5                    7.0860
# 16  2029       1               1102.0                    7.1542
# 17  2029       2               2508.0                    3.9840
# 18  2029       3               3097.0                    3.1175
# 19  2029       4               1653.0                    7.0860
#
#     GridElectricityPrice (USD / kWh)  SolarUnitsGeneration in Kwh/KwP  \
# 0                               0.15                              0.0
# 1                               0.20                              1.4
# 2                               0.25                              1.8
# 3                               0.35                              0.8
# 4                               0.15                              0.0
# 5                               0.20                              1.4
# 6                               0.25                              1.8
# 7                               0.35                              0.8
# 8                               0.15                              0.0
# 9                               0.20                              1.4
# 10                              0.25                              1.8
# 11                              0.35                              0.8
# 12                              0.15                              0.0
# 13                              0.20                              1.4
# 14                              0.25                              1.8
# 15                              0.35                              0.8
# 16                              0.15                              0.0
# 17                              0.20                              1.4
# 18                              0.25                              1.8
# 19                              0.35                              0.8
#
#     TotalEnergyRequirement
# 0                 484.1542
# 1                 705.9840
# 2                 732.1175
# 3                 484.0860
# 4                 484.1542
# 5                1200.9840
# 6                1236.1175
# 7                 727.0860
# 8                1015.1542
# 9                1767.9840
# 10               1263.1175
# 11               1015.0860
# 12               1128.1542
# 13               2217.4840
# 14               2150.1175
# 15               1365.5860
# 16               1109.1542
# 17               2511.9840
# 18               3100.1175
# 19               1660.0860

# %% [markdown]
# ## Some fixed parameters

# %%
battery_max_buy_overall = 2000
C_rate = 0.5
grid_upper_limit_per_slot = 1750
present_solar = 500
available_solar_to_buy_overall = 200
capex_budget_per_year = 60000

# %% [markdown]
# ## Infrastructure costs

# %%
infra_costs_5yr
# Out:
#    Year  Battery(USD/kWh)  SolarPV(USD/kWp)  Charger 50KW (USD/unit)  \
# 0  2025               300               450                     1000
# 1  2026               286               450                     1000
# 2  2027               272               450                     1000
# 3  2028               259               450                     1000
# 4  2029               247               450                     1000
#
#    Charger 400KW(USD/unit)
# 0                     2500
# 1                     2500
# 2                     2500
# 3                     2500
# 4                     2500

# %%
# Create dictionaries for cost inputs
battery_cost = dict(zip(infra_costs_5yr["Year"], infra_costs_5yr["Battery(USD/kWh)"]))
solar_cost = dict(zip(infra_costs_5yr["Year"], infra_costs_5yr["SolarPV(USD/kWp)"]))
charger50_cost = dict(zip(infra_costs_5yr["Year"], infra_costs_5yr["Charger 50KW (USD/unit)"]))
charger400_cost = dict(zip(infra_costs_5yr["Year"], infra_costs_5yr["Charger 400KW(USD/unit)"]))

battery_cost, solar_cost, charger50_cost, charger400_cost
# Out:
# ({2025: 300, 2026: 286, 2027: 272, 2028: 259, 2029: 247},
#  {2025: 450, 2026: 450, 2027: 450, 2028: 450, 2029: 450},
#  {2025: 1000, 2026: 1000, 2027: 1000, 2028: 1000, 2029: 1000},
#  {2025: 2500, 2026: 2500, 2027: 2500, 2028: 2500, 2029: 2500})

# %% [markdown]
# ## Optimization

# %% [markdown]
# ## Defining various lists and dictionaries related to slots for ease of use in constraints¶

# %%
import gurobipy as gp
from gurobipy import GRB

model = gp.Model('5 Year CAPEX and OPEX Planning')

## Defining lists and dictionaries ##

years = sorted(slot_data["Year"].unique())
slots = sorted(slot_data["SlotID"].unique())

slot_charging_requirement = {
    (row.Year, row.SlotID): row.ChargingRequirement
    for _, row in slot_data.iterrows()
}

slot_baseload = {
    (row.Year, row.SlotID): row["BaseLoadConsumption(kWh)"]
    for _, row in slot_data.iterrows()
}

slot_grid_price = {
    (row.Year, row.SlotID): row["GridElectricityPrice (USD / kWh)"]
    for _, row in slot_data.iterrows()
}

slot_solar_factor = {
    (row.Year, row.SlotID): row["SolarUnitsGeneration in Kwh/KwP"]
    for _, row in slot_data.iterrows()
}

slot_total_demand = {
    (row.Year, row.SlotID): row.TotalEnergyRequirement
    for _, row in slot_data.iterrows()
}
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2674748
# Academic license - for non-commercial use only - expires 2026-06-03

# %%
slot_charging_requirement
# Out:
# {(2025.0, 1.0): 477.0,
#  (2025.0, 2.0): 702.0,
#  (2025.0, 3.0): 729.0,
#  (2025.0, 4.0): 477.0,
#  (2026.0, 1.0): 477.0,
#  (2026.0, 2.0): 1197.0,
#  (2026.0, 3.0): 1233.0,
#  (2026.0, 4.0): 720.0,
#  (2027.0, 1.0): 1008.0,
#  (2027.0, 2.0): 1764.0,
#  (2027.0, 3.0): 1260.0,
#  (2027.0, 4.0): 1008.0,
#  (2028.0, 1.0): 1121.0,
#  (2028.0, 2.0): 2213.5,
#  (2028.0, 3.0): 2147.0,
#  (2028.0, 4.0): 1358.5,
#  (2029.0, 1.0): 1102.0,
#  (2029.0, 2.0): 2508.0,
#  (2029.0, 3.0): 3097.0,
#  (2029.0, 4.0): 1653.0}

# %%
slot_baseload
# Out:
# {(2025.0, 1.0): 7.1542,
#  (2025.0, 2.0): 3.984,
#  (2025.0, 3.0): 3.1175,
#  (2025.0, 4.0): 7.086,
#  (2026.0, 1.0): 7.1542,
#  (2026.0, 2.0): 3.984,
#  (2026.0, 3.0): 3.1175,
#  (2026.0, 4.0): 7.086,
#  (2027.0, 1.0): 7.1542,
#  (2027.0, 2.0): 3.984,
#  (2027.0, 3.0): 3.1175,
#  (2027.0, 4.0): 7.086,
#  (2028.0, 1.0): 7.1542,
#  (2028.0, 2.0): 3.984,
#  (2028.0, 3.0): 3.1175,
#  (2028.0, 4.0): 7.086,
#  (2029.0, 1.0): 7.1542,
#  (2029.0, 2.0): 3.984,
#  (2029.0, 3.0): 3.1175,
#  (2029.0, 4.0): 7.086}

# %%
slot_grid_price
# Out:
# {(2025.0, 1.0): 0.15,
#  (2025.0, 2.0): 0.2,
#  (2025.0, 3.0): 0.25,
#  (2025.0, 4.0): 0.35,
#  (2026.0, 1.0): 0.15,
#  (2026.0, 2.0): 0.2,
#  (2026.0, 3.0): 0.25,
#  (2026.0, 4.0): 0.35,
#  (2027.0, 1.0): 0.15,
#  (2027.0, 2.0): 0.2,
#  (2027.0, 3.0): 0.25,
#  (2027.0, 4.0): 0.35,
#  (2028.0, 1.0): 0.15,
#  (2028.0, 2.0): 0.2,
#  (2028.0, 3.0): 0.25,
#  (2028.0, 4.0): 0.35,
#  (2029.0, 1.0): 0.15,
#  (2029.0, 2.0): 0.2,
#  (2029.0, 3.0): 0.25,
#  (2029.0, 4.0): 0.35}

# %%
slot_solar_factor
# Out:
# {(2025.0, 1.0): 0.0,
#  (2025.0, 2.0): 1.4,
#  (2025.0, 3.0): 1.8,
#  (2025.0, 4.0): 0.8,
#  (2026.0, 1.0): 0.0,
#  (2026.0, 2.0): 1.4,
#  (2026.0, 3.0): 1.8,
#  (2026.0, 4.0): 0.8,
#  (2027.0, 1.0): 0.0,
#  (2027.0, 2.0): 1.4,
#  (2027.0, 3.0): 1.8,
#  (2027.0, 4.0): 0.8,
#  (2028.0, 1.0): 0.0,
#  (2028.0, 2.0): 1.4,
#  (2028.0, 3.0): 1.8,
#  (2028.0, 4.0): 0.8,
#  (2029.0, 1.0): 0.0,
#  (2029.0, 2.0): 1.4,
#  (2029.0, 3.0): 1.8,
#  (2029.0, 4.0): 0.8}

# %%
slot_total_demand
# Out:
# {(2025.0, 1.0): 484.1542,
#  (2025.0, 2.0): 705.984,
#  (2025.0, 3.0): 732.1175,
#  (2025.0, 4.0): 484.086,
#  (2026.0, 1.0): 484.1542,
#  (2026.0, 2.0): 1200.984,
#  (2026.0, 3.0): 1236.1175,
#  (2026.0, 4.0): 727.086,
#  (2027.0, 1.0): 1015.1542,
#  (2027.0, 2.0): 1767.984,
#  (2027.0, 3.0): 1263.1175,
#  (2027.0, 4.0): 1015.086,
#  (2028.0, 1.0): 1128.1542,
#  (2028.0, 2.0): 2217.484,
#  (2028.0, 3.0): 2150.1175,
#  (2028.0, 4.0): 1365.586,
#  (2029.0, 1.0): 1109.1542,
#  (2029.0, 2.0): 2511.984,
#  (2029.0, 3.0): 3100.1175,
#  (2029.0, 4.0): 1660.086}

# %% [markdown]
# ## Decision Variables ##

# %% [markdown]
# ## These have been formulated in the same way as the report, use of for loops in certain places for convenience.¶

# %%
solar_buy_year = model.addVars(years,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of solar to buy each year')
solar_used_year_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of solar energy used in each slot each year')
solar_export_year_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of solar energy exported in each slot each year')
solar_stored_battery_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of solar energy stored in batteries in each slot each year')

battery_buy_year = model.addVars(years,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of battery capacity to buy each year')
battery_used_year_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of energy used from batteries in each slot each year')
battery_export_year_slot =  model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of energy exported from batteries to grid in each slot each year')
battery_start_year_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Energy in battery at start of each slot each year')

grid_year_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0,name = 'Amount of energy used from the grid in slot each slot each year')

nocfifty = model.addVars(years,vtype = GRB.INTEGER,lb = 0,name = 'Number of 50 kW Chargers to buy each year')
nocfourhundred = model.addVars(years,vtype = GRB.INTEGER,lb = 0,name = 'Number of 400 kW Chargers to buy each year')

battery_capacity_per_year = model.addVars(years,vtype = GRB.CONTINUOUS,lb = 0)
for idx, y in enumerate(years):
    if idx == 0:   # first year (2025)
        model.addConstr(
            battery_capacity_per_year[y] == battery_buy_year[y]
        )
    else:
        prev = years[idx - 1]
        model.addConstr(
            battery_capacity_per_year[y] ==
                battery_capacity_per_year[prev] + battery_buy_year[y]
        )
        
nocfifty_cap_per_year = model.addVars(years,vtype = GRB.INTEGER,lb = 0)
nocfourhundred_cap_per_year = model.addVars(years,vtype = GRB.INTEGER,lb = 0)

for idx,y in enumerate(years):
    if idx == 0:
        model.addConstr(nocfifty_cap_per_year[y] == nocfifty[y])
        model.addConstr(nocfourhundred_cap_per_year[y] == nocfourhundred[y])
    else:
        prev = years[idx - 1]
        model.addConstr(nocfifty_cap_per_year[y] == nocfifty_cap_per_year[prev] + nocfifty[y])
        model.addConstr(nocfourhundred_cap_per_year[y] == nocfourhundred_cap_per_year[prev] + nocfourhundred[y])

# %% [markdown]
# ## Solar generation as a constraint, same as report formulation

# %%
solar_gen_year_slot = model.addVars(years,slots,vtype = GRB.CONTINUOUS,lb = 0)

for y in years:
    for s in slots:
        model.addConstr(solar_gen_year_slot[y,s] == (present_solar +(gp.quicksum(solar_buy_year[k] for k in years if k<=y)))*slot_solar_factor[(y,s)])

# %%
slot_solar_factor
# Out:
# {(2025.0, 1.0): 0.0,
#  (2025.0, 2.0): 1.4,
#  (2025.0, 3.0): 1.8,
#  (2025.0, 4.0): 0.8,
#  (2026.0, 1.0): 0.0,
#  (2026.0, 2.0): 1.4,
#  (2026.0, 3.0): 1.8,
#  (2026.0, 4.0): 0.8,
#  (2027.0, 1.0): 0.0,
#  (2027.0, 2.0): 1.4,
#  (2027.0, 3.0): 1.8,
#  (2027.0, 4.0): 0.8,
#  (2028.0, 1.0): 0.0,
#  (2028.0, 2.0): 1.4,
#  (2028.0, 3.0): 1.8,
#  (2028.0, 4.0): 0.8,
#  (2029.0, 1.0): 0.0,
#  (2029.0, 2.0): 1.4,
#  (2029.0, 3.0): 1.8,
#  (2029.0, 4.0): 0.8}

# %% [markdown]
# ## Constraints (Same as report formulation)

# %%
model.addConstr(gp.quicksum(solar_buy_year[y] for y in years) <= available_solar_to_buy_overall)
model.addConstr(gp.quicksum(battery_buy_year[y] for y in years) <= battery_max_buy_overall)

for y in years:
    for s in slots:
        model.addConstr(solar_used_year_slot[y,s] + grid_year_slot[y,s] + battery_used_year_slot[y,s] == slot_total_demand[y,s])
        model.addConstr(solar_export_year_slot[y,s] + solar_stored_battery_slot[y,s] + solar_used_year_slot[y,s] == solar_gen_year_slot[y,s])
       
        #if y == 2025:
            #model.addConstr(battery_start_year_slot[2025,1] == 0)   
        #else:
            #model.addConstr(battery_start_year_slot[y,1] == battery_start_year_slot[y-1,4] + solar_stored_battery_slot[y-1,4] - 
                           # battery_used_year_slot[y-1,4] - battery_export_year_slot[y-1,4])         
        if s == 1:
            model.addConstr(battery_start_year_slot[y,s] == battery_start_year_slot[y,4] + solar_stored_battery_slot[y,4] - 
                            battery_used_year_slot[y,4] - battery_export_year_slot[y,4])
        else:
            model.addConstr(battery_start_year_slot[y,s] == battery_start_year_slot[y,s-1] + solar_stored_battery_slot[y,s-1] -
                           battery_used_year_slot[y,s-1] - battery_export_year_slot[y,s-1])
        model.addConstr(battery_used_year_slot[y,s] + battery_export_year_slot[y,s] <= C_rate*battery_capacity_per_year[y])
        model.addConstr(battery_start_year_slot[y,s] <= battery_capacity_per_year[y])
        model.addConstr((nocfifty_cap_per_year[y] * 50 + nocfourhundred_cap_per_year[y] * 400) * 6 >= slot_charging_requirement[y,s])
        model.addConstr(grid_year_slot[y,s] <= grid_upper_limit_per_slot)

# %%
slot_charging_requirement
# Out:
# {(2025.0, 1.0): 477.0,
#  (2025.0, 2.0): 702.0,
#  (2025.0, 3.0): 729.0,
#  (2025.0, 4.0): 477.0,
#  (2026.0, 1.0): 477.0,
#  (2026.0, 2.0): 1197.0,
#  (2026.0, 3.0): 1233.0,
#  (2026.0, 4.0): 720.0,
#  (2027.0, 1.0): 1008.0,
#  (2027.0, 2.0): 1764.0,
#  (2027.0, 3.0): 1260.0,
#  (2027.0, 4.0): 1008.0,
#  (2028.0, 1.0): 1121.0,
#  (2028.0, 2.0): 2213.5,
#  (2028.0, 3.0): 2147.0,
#  (2028.0, 4.0): 1358.5,
#  (2029.0, 1.0): 1102.0,
#  (2029.0, 2.0): 2508.0,
#  (2029.0, 3.0): 3097.0,
#  (2029.0, 4.0): 1653.0}

# %% [markdown]
# ## Minimize capex + opex - revenue (solar + battery).Capex consists of new stuff you buy and opex is buying from the grid.

# %%
battery_cost      = infra_costs_5yr.set_index("Year")["Battery(USD/kWh)"].to_dict()
solar_cost        = infra_costs_5yr.set_index("Year")["SolarPV(USD/kWp)"].to_dict()
charger50_cost    = infra_costs_5yr.set_index("Year")["Charger 50KW (USD/unit)"].to_dict()
charger400_cost   = infra_costs_5yr.set_index("Year")["Charger 400KW(USD/unit)"].to_dict()

capex_year = {}
opex_year = {}
#solar_export_rev_year = {}
#battery_export_rev_year = {}

for y in years:

    # CAPEX
    capex_year[y] = (
        solar_cost[y]   * solar_buy_year[y] +
        battery_cost[y] * battery_buy_year[y] +
        charger50_cost[y]  * nocfifty[y] +
        charger400_cost[y] * nocfourhundred[y]
    )

    model.addConstr(capex_year[y] <= 60000)

    # OPEX
    opex_year[y] = 365 * gp.quicksum(
        grid_year_slot[y,s] * slot_grid_price[(y,s)] for s in slots
    )

    # Revenues
    #solar_export_rev_year[y] = 365 * gp.quicksum(
    #solar_export_year_slot[y,s] * slot_grid_price[(y,s)] for s in slots
    #)

    #battery_export_rev_year[y] = 365 * gp.quicksum(
     #   battery_export_year_slot[y,s] * slot_grid_price[(y,s)] for s in slots
    #)

# Total objective over 5 years
model.setObjective(
    gp.quicksum(capex_year[y] for y in years) +
    gp.quicksum(opex_year[y] for y in years),GRB.MINIMIZE)
    #gp.quicksum(solar_export_rev_year[y] for y in years) -
    #gp.quicksum(battery_export_rev_year[y] for y in years),GRB.MINIMIZE)

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 182 rows, 195 columns and 537 nonzeros
# Model fingerprint: 0x07c3a834
# Variable types: 175 continuous, 20 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 3e+03]
#   Objective range  [5e+01, 3e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 6e+04]
# Presolve removed 89 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 93 rows, 96 columns, 298 nonzeros
# Variable types: 84 continuous, 12 integer (0 binary)
# Found heuristic solution: objective 1356434.6232
#
# Root relaxation: objective 1.199381e+06, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1199381.46    0    2 1356434.62 1199381.46  11.6%     -    0s
# H    0     0                    1200943.9585 1199381.46  0.13%     -    0s
#
# Cutting planes:
#   MIR: 1
#   StrongCG: 1
#
# Explored 1 nodes (59 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 1.20094e+06 1.35643e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200943958542e+06, best bound 1.200943958542e+06, gap 0.0000%

# %% [markdown]
# ## Display of results year by year slot by slot. Used AI for the coding (attached in appendix of report)

# %%
if model.status == GRB.OPTIMAL:
    print("\n==========================")
    print(" TOTAL COST OVER 5 YEARS ")
    print("==========================")
    print(f"Objective Value: {model.ObjVal:,.2f}\n")

    # ========= YEARLY REPORTS ========= #
    for y in years:
        print("\n====================================")
        print(f" YEAR {y} RESULTS")
        print("====================================")

        # CAPEX Categories
        print("\n---- CAPEX ----")
        print(f"Solar Bought (kWp): {solar_buy_year[y].X:,.2f}")
        print(f"Battery Bought (kWh): {battery_buy_year[y].X:,.2f}")
        print(f"50 kW Chargers Bought: {nocfifty[y].X:,.0f}")
        print(f"400 kW Chargers Bought: {nocfourhundred[y].X:,.0f}")
        print(f"Total CAPEX (USD): {capex_year[y].getValue():,.2f}")

        # OPEX
        print("\n---- OPEX ----")
        print(f"Grid OPEX per Year (USD): {opex_year[y].getValue():,.2f}")

        # Revenues
        print("\n---- EXPORT REVENUES ----")
       # print(f"Solar Export Revenue (USD): {solar_export_rev_year[y].getValue():,.2f}")
       # print(f"Battery Export Revenue (USD): {battery_export_rev_year[y].getValue():,.2f}")

        # ========= SLOT DETAILS ========= #
        print("\n---- SLOT DETAILS ----")
        for s in slots:
            print(f"\n Slot {s}:")

            # Grid energy
            print(f"  Grid Energy Used (kWh): {grid_year_slot[y,s].X:.2f}")

            # Solar
            print("  Solar:")
            print(f"    Generated: {solar_gen_year_slot[y,s].X:.2f}")
            print(f"    Used:      {solar_used_year_slot[y,s].X:.2f}")
            print(f"    Stored:    {solar_stored_battery_slot[y,s].X:.2f}")
            print(f"    Exported:  {solar_export_year_slot[y,s].X:.2f}")

            # Battery
            print("  Battery:")
            print(f"    SOC Start:  {battery_start_year_slot[y,s].X:.2f}")
            print(f"    Used:       {battery_used_year_slot[y,s].X:.2f}")
            print(f"    Exported:   {battery_export_year_slot[y,s].X:.2f}")

            # Energy balance check
            lhs = (
                solar_used_year_slot[y,s].X +
                grid_year_slot[y,s].X +
                battery_used_year_slot[y,s].X
            )
            rhs = slot_total_demand[(y,s)]
            diff = lhs - rhs

            print("\n  Energy Balance Check:")
            print(f"    LHS = {lhs:.3f}, RHS = {rhs:.3f}, Difference = {diff:.6f}")

    print("\nAll reports generated successfully.")

else:
    print("Model not optimal. Status:", model.status)
# Out:
# ==========================
#  TOTAL COST OVER 5 YEARS
# ==========================
# Objective Value: 1,200,943.96
#
#
# ====================================
#  YEAR 2025 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought (kWp): 66.67
# Battery Bought (kWh): 91.67
# 50 kW Chargers Bought: 0
# 400 kW Chargers Bought: 1
# Total CAPEX (USD): 60,000.00
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 23,998.07
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 438.32
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  45.83
#     Used:       45.83
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 484.154, RHS = 484.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 793.33
#     Used:      705.98
#     Stored:    0.00
#     Exported:  87.35
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 705.984, RHS = 705.984, Difference = 0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 1020.00
#     Used:      732.12
#     Stored:    76.59
#     Exported:  211.30
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 732.117, RHS = 732.117, Difference = 0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 453.33
#     Used:      453.33
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  76.59
#     Used:       30.75
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 484.086, RHS = 484.086, Difference = -0.000000
#
# ====================================
#  YEAR 2026 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought (kWp): 133.33
# Battery Bought (kWh): 0.00
# 50 kW Chargers Bought: 0
# 400 kW Chargers Bought: 0
# Total CAPEX (USD): 60,000.00
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 59,731.71
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 484.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 484.154, RHS = 484.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 242.93
#   Solar:
#     Generated: 980.00
#     Used:      958.05
#     Stored:    21.95
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1200.984, RHS = 1200.984, Difference = 0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 1260.00
#     Used:      1236.12
#     Stored:    23.88
#     Exported:  0.00
#   Battery:
#     SOC Start:  21.95
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1236.118, RHS = 1236.118, Difference = 0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 121.25
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  45.83
#     Used:       45.83
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 727.086, RHS = 727.086, Difference = 0.000000
#
# ====================================
#  YEAR 2027 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought (kWp): 0.00
# Battery Bought (kWh): 88.57
# 50 kW Chargers Bought: 0
# 400 kW Chargers Bought: 0
# Total CAPEX (USD): 24,090.59
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 166,533.41
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 1015.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1015.154, RHS = 1015.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 881.22
#   Solar:
#     Generated: 980.00
#     Used:      886.77
#     Stored:    93.23
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1767.984, RHS = 1767.984, Difference = 0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 1260.00
#     Used:      1260.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  93.23
#     Used:       3.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1263.118, RHS = 1263.118, Difference = 0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 364.97
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  90.12
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1015.086, RHS = 1015.086, Difference = 0.000000
#
# ====================================
#  YEAR 2028 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought (kWp): 0.00
# Battery Bought (kWh): 0.00
# 50 kW Chargers Bought: 0
# 400 kW Chargers Bought: 1
# Total CAPEX (USD): 2,500.00
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 329,661.03
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 1128.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1128.154, RHS = 1128.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 1417.72
#   Solar:
#     Generated: 980.00
#     Used:      709.65
#     Stored:    270.35
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 2217.484, RHS = 2217.484, Difference = -0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 800.00
#   Solar:
#     Generated: 1260.00
#     Used:      1260.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  180.23
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 2150.117, RHS = 2150.117, Difference = -0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 715.47
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  90.12
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1365.586, RHS = 1365.586, Difference = 0.000000
#
# ====================================
#  YEAR 2029 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought (kWp): 0.00
# Battery Bought (kWh): 0.00
# 50 kW Chargers Bought: 0
# 400 kW Chargers Bought: 0
# Total CAPEX (USD): 0.00
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 474,429.16
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 1109.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1109.154, RHS = 1109.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 1712.22
#   Solar:
#     Generated: 980.00
#     Used:      709.65
#     Stored:    270.35
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 2511.984, RHS = 2511.984, Difference = -0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 1750.00
#   Solar:
#     Generated: 1260.00
#     Used:      1260.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  180.23
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 3100.117, RHS = 3100.117, Difference = -0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 1009.97
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  90.12
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1660.086, RHS = 1660.086, Difference = 0.000000
#
# All reports generated successfully.

# %%
if model.status == GRB.OPTIMAL:
    print("\n==========================")
    print(" TOTAL COST OVER 5 YEARS ")
    print("==========================")
    print(f"Objective Value: {model.ObjVal:,.2f}\n")

    # ========= YEARLY REPORTS ========= #
    for y in years:
        print("\n====================================")
        print(f" YEAR {y} RESULTS")
        print("====================================")

        # CAPEX Categories
        print("\n---- CAPEX ----")
        print(f"Solar Bought This Year (kWp): {solar_buy_year[y].X:,.2f}")
        print(f"Battery Bought This Year (kWh): {battery_buy_year[y].X:,.2f}")
        print(f"50 kW Chargers Bought This Year: {nocfifty[y].X:,.0f}")
        print(f"400 kW Chargers Bought This Year: {nocfourhundred[y].X:,.0f}")
        print(f"Total CAPEX (USD): {capex_year[y].getValue():,.2f}")

        # CAPACITY AVAILABLE AFTER PURCHASES
        print("\n---- INSTALLED CAPACITY (CUMULATIVE) ----")
        print(f"Total Battery Capacity Available (kWh): {battery_capacity_per_year[y].X:,.2f}")
        print(f"Total 50 kW Chargers Available: {nocfifty_cap_per_year[y].X:,.0f}")
        print(f"Total 400 kW Chargers Available: {nocfourhundred_cap_per_year[y].X:,.0f}")

        # OPEX
        print("\n---- OPEX ----")
        print(f"Grid OPEX per Year (USD): {opex_year[y].getValue():,.2f}")

        # Revenues
        print("\n---- EXPORT REVENUES ----")
        #print(f"Solar Export Revenue (USD): {solar_export_rev_year[y].getValue():,.2f}")
        #print(f"Battery Export Revenue (USD): {battery_export_rev_year[y].getValue():,.2f}")

        # ========= SLOT DETAILS ========= #
        print("\n---- SLOT DETAILS ----")
        for s in slots:
            print(f"\n Slot {s}:")

            # Grid energy
            print(f"  Grid Energy Used (kWh): {grid_year_slot[y,s].X:.2f}")

            # Solar
            print("  Solar:")
            print(f"    Generated: {solar_gen_year_slot[y,s].X:.2f}")
            print(f"    Used:      {solar_used_year_slot[y,s].X:.2f}")
            print(f"    Stored:    {solar_stored_battery_slot[y,s].X:.2f}")
            print(f"    Exported:  {solar_export_year_slot[y,s].X:.2f}")

            # Battery
            print("  Battery:")
            print(f"    SOC Start:  {battery_start_year_slot[y,s].X:.2f}")
            print(f"    Used:       {battery_used_year_slot[y,s].X:.2f}")
            print(f"    Exported:   {battery_export_year_slot[y,s].X:.2f}")

            # Energy balance check
            lhs = (
                solar_used_year_slot[y,s].X +
                grid_year_slot[y,s].X +
                battery_used_year_slot[y,s].X
            )
            rhs = slot_total_demand[(y,s)]
            diff = lhs - rhs

            print("\n  Energy Balance Check:")
            print(f"    LHS = {lhs:.3f}, RHS = {rhs:.3f}, Difference = {diff:.6f}")

    print("\nAll reports generated successfully.")

else:
    print("Model not optimal. Status:", model.status)
# Out:
# ==========================
#  TOTAL COST OVER 5 YEARS
# ==========================
# Objective Value: 1,200,943.96
#
#
# ====================================
#  YEAR 2025 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought This Year (kWp): 66.67
# Battery Bought This Year (kWh): 91.67
# 50 kW Chargers Bought This Year: 0
# 400 kW Chargers Bought This Year: 1
# Total CAPEX (USD): 60,000.00
#
# ---- INSTALLED CAPACITY (CUMULATIVE) ----
# Total Battery Capacity Available (kWh): 91.67
# Total 50 kW Chargers Available: 0
# Total 400 kW Chargers Available: 1
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 23,998.07
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 438.32
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  45.83
#     Used:       45.83
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 484.154, RHS = 484.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 793.33
#     Used:      705.98
#     Stored:    0.00
#     Exported:  87.35
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 705.984, RHS = 705.984, Difference = 0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 1020.00
#     Used:      732.12
#     Stored:    76.59
#     Exported:  211.30
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 732.117, RHS = 732.117, Difference = 0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 453.33
#     Used:      453.33
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  76.59
#     Used:       30.75
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 484.086, RHS = 484.086, Difference = -0.000000
#
# ====================================
#  YEAR 2026 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought This Year (kWp): 133.33
# Battery Bought This Year (kWh): 0.00
# 50 kW Chargers Bought This Year: 0
# 400 kW Chargers Bought This Year: 0
# Total CAPEX (USD): 60,000.00
#
# ---- INSTALLED CAPACITY (CUMULATIVE) ----
# Total Battery Capacity Available (kWh): 91.67
# Total 50 kW Chargers Available: 0
# Total 400 kW Chargers Available: 1
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 59,731.71
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 484.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 484.154, RHS = 484.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 242.93
#   Solar:
#     Generated: 980.00
#     Used:      958.05
#     Stored:    21.95
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1200.984, RHS = 1200.984, Difference = 0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 1260.00
#     Used:      1236.12
#     Stored:    23.88
#     Exported:  0.00
#   Battery:
#     SOC Start:  21.95
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1236.118, RHS = 1236.118, Difference = 0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 121.25
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  45.83
#     Used:       45.83
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 727.086, RHS = 727.086, Difference = 0.000000
#
# ====================================
#  YEAR 2027 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought This Year (kWp): 0.00
# Battery Bought This Year (kWh): 88.57
# 50 kW Chargers Bought This Year: 0
# 400 kW Chargers Bought This Year: 0
# Total CAPEX (USD): 24,090.59
#
# ---- INSTALLED CAPACITY (CUMULATIVE) ----
# Total Battery Capacity Available (kWh): 180.23
# Total 50 kW Chargers Available: 0
# Total 400 kW Chargers Available: 1
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 166,533.41
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 1015.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1015.154, RHS = 1015.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 881.22
#   Solar:
#     Generated: 980.00
#     Used:      886.77
#     Stored:    93.23
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1767.984, RHS = 1767.984, Difference = 0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 0.00
#   Solar:
#     Generated: 1260.00
#     Used:      1260.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  93.23
#     Used:       3.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1263.118, RHS = 1263.118, Difference = 0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 364.97
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  90.12
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1015.086, RHS = 1015.086, Difference = 0.000000
#
# ====================================
#  YEAR 2028 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought This Year (kWp): 0.00
# Battery Bought This Year (kWh): 0.00
# 50 kW Chargers Bought This Year: 0
# 400 kW Chargers Bought This Year: 1
# Total CAPEX (USD): 2,500.00
#
# ---- INSTALLED CAPACITY (CUMULATIVE) ----
# Total Battery Capacity Available (kWh): 180.23
# Total 50 kW Chargers Available: 0
# Total 400 kW Chargers Available: 2
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 329,661.03
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 1128.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1128.154, RHS = 1128.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 1417.72
#   Solar:
#     Generated: 980.00
#     Used:      709.65
#     Stored:    270.35
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 2217.484, RHS = 2217.484, Difference = -0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 800.00
#   Solar:
#     Generated: 1260.00
#     Used:      1260.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  180.23
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 2150.117, RHS = 2150.117, Difference = -0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 715.47
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  90.12
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1365.586, RHS = 1365.586, Difference = 0.000000
#
# ====================================
#  YEAR 2029 RESULTS
# ====================================
#
# ---- CAPEX ----
# Solar Bought This Year (kWp): 0.00
# Battery Bought This Year (kWh): 0.00
# 50 kW Chargers Bought This Year: 0
# 400 kW Chargers Bought This Year: 0
# Total CAPEX (USD): 0.00
#
# ---- INSTALLED CAPACITY (CUMULATIVE) ----
# Total Battery Capacity Available (kWh): 180.23
# Total 50 kW Chargers Available: 0
# Total 400 kW Chargers Available: 2
#
# ---- OPEX ----
# Grid OPEX per Year (USD): 474,429.16
#
# ---- EXPORT REVENUES ----
#
# ---- SLOT DETAILS ----
#
#  Slot 1:
#   Grid Energy Used (kWh): 1109.15
#   Solar:
#     Generated: 0.00
#     Used:      0.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       0.00
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1109.154, RHS = 1109.154, Difference = 0.000000
#
#  Slot 2:
#   Grid Energy Used (kWh): 1712.22
#   Solar:
#     Generated: 980.00
#     Used:      709.65
#     Stored:    270.35
#     Exported:  0.00
#   Battery:
#     SOC Start:  0.00
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 2511.984, RHS = 2511.984, Difference = -0.000000
#
#  Slot 3:
#   Grid Energy Used (kWh): 1750.00
#   Solar:
#     Generated: 1260.00
#     Used:      1260.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  180.23
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 3100.117, RHS = 3100.117, Difference = -0.000000
#
#  Slot 4:
#   Grid Energy Used (kWh): 1009.97
#   Solar:
#     Generated: 560.00
#     Used:      560.00
#     Stored:    0.00
#     Exported:  0.00
#   Battery:
#     SOC Start:  90.12
#     Used:       90.12
#     Exported:   0.00
#
#   Energy Balance Check:
#     LHS = 1660.086, RHS = 1660.086, Difference = 0.000000
#
# All reports generated successfully.

# %% [markdown]
# ## Exporting in report format , used AI (shown in appendix of report)

# %%
if model.status == GRB.OPTIMAL:
    
    results_data = {'Metric': []}
    for y in years:
        results_data[str(y)] = []
    
    def add_row(metric_name, year_values):
        results_data['Metric'].append(metric_name)
        for i, y in enumerate(years):
            results_data[str(y)].append(year_values[i])
    
    # Collect data
    capex_values = [capex_year[y].getValue() for y in years]
    opex_values = [opex_year[y].getValue() for y in years]
    charger50_values = [nocfifty[y].X for y in years]
    charger400_values = [nocfourhundred[y].X for y in years]
    solar_values = [solar_buy_year[y].X for y in years]
    battery_values = [battery_buy_year[y].X for y in years]
    
    # Total cost = CAPEX + OPEX (no revenue)
    total_cost_values = [capex_year[y].getValue() + opex_year[y].getValue() for y in years]
    
    # Add rows
    add_row('CAPEXCost', capex_values)
    add_row('OPEXCost', opex_values)
    add_row('#50KWChargers', charger50_values)
    add_row('#400KWChargers', charger400_values)
    add_row('SolarCapacity', solar_values)
    add_row('BatteryCapacity', battery_values)
    add_row('SolarExportRevenue', [0.0] * len(years))  # Always 0
    add_row('BatteryExportRevenue',[0.0]*len(years))
    add_row('TotalCost', total_cost_values)
    
    # Save to CSV
    df_results = pd.DataFrame(results_data)
    df_results.to_csv('optimization_results_no_export.csv', index=False)
    
    print("\n✓ Results saved to: optimization_results_no_export.csv")
    print(df_results)
# Out:
# ✓ Results saved to: optimization_results_no_export.csv
#                  Metric          2025           2026           2027  \
# 0             CAPEXCost  60000.000000   60000.000000   24090.586667
# 1              OPEXCost  23998.067450   59731.713450  166533.405325
# 2         #50KWChargers      0.000000       0.000000       0.000000
# 3        #400KWChargers      1.000000       0.000000       0.000000
# 4         SolarCapacity     66.666667     133.333333       0.000000
# 5       BatteryCapacity     91.666667       0.000000      88.568333
# 6    SolarExportRevenue      0.000000       0.000000       0.000000
# 7  BatteryExportRevenue      0.000000       0.000000       0.000000
# 8             TotalCost  83998.067450  119731.713450  190623.991992
#
#             2028           2029
# 0    2500.000000       0.000000
# 1  329661.030325  474429.155325
# 2       0.000000       0.000000
# 3       1.000000       0.000000
# 4       0.000000       0.000000
# 5       0.000000       0.000000
# 6       0.000000       0.000000
# 7       0.000000       0.000000
# 8  332161.030325  474429.155325

# %% [markdown]
# ## Operational data, outputs csv file that has for each year, each slot how much solar energy was used,how much was exported, stored to the battery and so on

# %%
if model.status == GRB.OPTIMAL:
    
    operational_data = []
    
    for y in years:
        fleet_size = len(vehicle_df[vehicle_df['Year'] == y])
        
        for s in slots:
            row = {
                'Year': y,
                'Slot': s,
                'FleetSize': fleet_size,
                'ChargingRequirement_kWh': slot_charging_requirement[(y, s)],
                'BaseloadRequirement_kWh': slot_baseload[(y, s)],
                'TotalDemand_kWh': slot_total_demand[(y, s)],
                'SolarGenerated_kWh': solar_gen_year_slot[y, s].X,
                'SolarUsed_kWh': solar_used_year_slot[y, s].X,
                'SolarStored_kWh': solar_stored_battery_slot[y, s].X,
                'SolarExported_kWh': solar_export_year_slot[y, s].X,
                'BatterySOC_Start_kWh': battery_start_year_slot[y, s].X,
                'BatteryUsed_kWh': battery_used_year_slot[y, s].X,
                'GridUsed_kWh': grid_year_slot[y, s].X,
            }
            operational_data.append(row)
    
    df_operational = pd.DataFrame(operational_data)
    df_operational.to_csv('operational_details.csv', index=False)
    print("✓ Saved: operational_details.csv")
    print(df_operational.head(10))
# Out:
# ✓ Saved: operational_details.csv
#    Year  Slot  FleetSize  ChargingRequirement_kWh  BaseloadRequirement_kWh  \
# 0  2025     1         10                    477.0                   7.1542
# 1  2025     2         10                    702.0                   3.9840
# 2  2025     3         10                    729.0                   3.1175
# 3  2025     4         10                    477.0                   7.0860
# 4  2026     1         15                    477.0                   7.1542
# 5  2026     2         15                   1197.0                   3.9840
# 6  2026     3         15                   1233.0                   3.1175
# 7  2026     4         15                    720.0                   7.0860
# 8  2027     1         20                   1008.0                   7.1542
# 9  2027     2         20                   1764.0                   3.9840
#
#    TotalDemand_kWh  SolarGenerated_kWh  SolarUsed_kWh  SolarStored_kWh  \
# 0         484.1542            0.000000       0.000000         0.000000
# 1         705.9840          793.333333     705.984000         0.000000
# 2         732.1175         1020.000000     732.117500        76.586000
# 3         484.0860          453.333333     453.333333         0.000000
# 4         484.1542            0.000000       0.000000         0.000000
# 5        1200.9840          980.000000     958.049167        21.950833
# 6        1236.1175         1260.000000    1236.117500        23.882500
# 7         727.0860          560.000000     560.000000         0.000000
# 8        1015.1542            0.000000       0.000000         0.000000
# 9        1767.9840          980.000000     886.765000        93.235000
#
#    SolarExported_kWh  BatterySOC_Start_kWh  BatteryUsed_kWh  GridUsed_kWh
# 0           0.000000             45.833333        45.833333    438.320867
# 1          87.349333              0.000000         0.000000      0.000000
# 2         211.296500              0.000000         0.000000      0.000000
# 3           0.000000             76.586000        30.752667      0.000000
# 4           0.000000              0.000000         0.000000    484.154200
# 5           0.000000              0.000000         0.000000    242.934833
# 6           0.000000             21.950833         0.000000      0.000000
# 7           0.000000             45.833333        45.833333    121.252667
# 8           0.000000              0.000000         0.000000   1015.154200
# 9           0.000000              0.000000         0.000000    881.219000
